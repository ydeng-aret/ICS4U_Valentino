# %%
import random
list = ["+", "-", "/", "*"]

x = random.randint(0,25)
y = random.randint(0,25)
z = random.choice(list)

for i in range(50):
    x = random.randint(0,25)
    y = random.randint(0,25)
    z = random.choice(list)
    if z == "+":
        a = x + y
        print(f"{x} + {y} = {a}")
    elif z == "-":
        a = x - y
        print(f"{x} - {y} = {a}")
    elif z == "/":
        if y == 0:
            continue
        else:
            a = x / y
            a = round(a,2)
            print(f"{x} / {y} = {a}")
    elif z == "*":
        a = x * y
        print(f"{x} * {y} = {a}")
# Out:
# 6 * 22 = 132
# 6 * 0 = 0
# 19 * 20 = 380
# 14 * 13 = 182
# 4 * 11 = 44
# 13 + 11 = 24
# 18 / 25 = 0.72
# 21 - 24 = -3
# 14 - 17 = -3
# 24 * 9 = 216
# 18 / 1 = 18.0
# 24 - 1 = 23
# 1 / 8 = 0.12
# 3 / 18 = 0.17
# 1 * 7 = 7
# 23 + 8 = 31
# 18 / 20 = 0.9
# 4 - 21 = -17
# 15 - 23 = -8
# 2 - 6 = -4
# 14 / 21 = 0.67
# 5 + 3 = 8
# 17 - 15 = 2
# 25 * 24 = 600
# 14 * 11 = 154
# 8 * 12 = 96
# 7 / 19 = 0.37
# 14 * 11 = 154
# 14 + 15 = 29
# 19 - 10 = 9
# 3 - 24 = -21
# 4 * 4 = 16
# 14 / 24 = 0.58
# 10 / 1 = 10.0
# 8 - 11 = -3
# 11 / 9 = 1.22
# 11 / 15 = 0.73
# 11 * 16 = 176
# 15 - 21 = -6
# 24 / 9 = 2.67
# 2 - 13 = -11
# 12 / 24 = 0.5
# 14 - 19 = -5
# 18 / 9 = 2.0
# 22 - 14 = 8
# 8 + 15 = 23
# 8 * 12 = 96
# 12 - 24 = -12
# 4 * 20 = 80
# 20 * 4 = 80
